# %%
# !pwd
# Out:
# /content

# %%
# 파이썬 버전 확인
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=6, micro=9, releaselevel='final', serial=0)

# %%
# 디스크 용량
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          69G   33G   37G  48% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# shm             5.8G     0  5.8G   0% /dev/shm
# tmpfs           6.4G   20K  6.4G   1% /var/colab
# /dev/sda1        75G   34G   41G  46% /opt/bin
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive            15G  7.5G  7.6G  50% /content/drive

# %%
# 메모리 정보
# !cat /proc/meminfo
# Out:
# MemTotal:       13333580 kB
# MemFree:        10588028 kB
# MemAvailable:   12457484 kB
# Buffers:           80680 kB
# Cached:          1934300 kB
# SwapCached:            0 kB
# Active:           982000 kB
# Inactive:        1444228 kB
# Active(anon):     381820 kB
# Inactive(anon):      368 kB
# Active(file):     600180 kB
# Inactive(file):  1443860 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               480 kB
# Writeback:             0 kB
# AnonPages:        411412 kB
# Mapped:           242208 kB
# Shmem:              1008 kB
# Slab:             177892 kB
# SReclaimable:     132584 kB
# SUnreclaim:        45308 kB
# KernelStack:        5104 kB
# PageTables:         6116 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6666788 kB
# Committed_AS:    3348480 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...

# %%
# GPU 사용가능여부 확인
# !nvidia-smi
# Out:
# Wed Feb 17 04:17:29 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/clovaai/CutMix-PyTorch.git
# Out:
# Cloning into 'CutMix-PyTorch'...
# remote: Enumerating objects: 43, done.
# remote: Total 43 (delta 0), reused 0 (delta 0), pack-reused 43
# Unpacking objects: 100% (43/43), done.

# %%
# %cd ./CutMix-PyTorch
# Out:
# [Errno 2] No such file or directory: './CutMix-PyTorch'
# /content/CutMix-PyTorch

# %%
# !python train.py --net_type pyramidnet --dataset cifar100 --depth 200 --alpha 240 --batch_size 64 --lr 0.25 --expname help --epochs 2 --beta 1.0 --cutmix_prob 0.5 --no-verbose
# Out:
# Files already downloaded and verified
# => creating model 'pyramidnet'
# DataParallel(
#   (module): PyramidNet(
#     (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(16, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn3): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(20, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn4): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# !python test.py \
--net_type pyramidnet \
--dataset cifar100 \
--batch_size 64 \
--depth 200 \
--alpha 240 \
--pretrained /content/drive/MyDrive/temp/model_best.pth.tar
# Out:
# => creating model 'pyramidnet'
# => loading checkpoint '/content/drive/MyDrive/temp/model_best.pth.tar'
# => loaded checkpoint '/content/drive/MyDrive/temp/model_best.pth.tar'
# DataParallel(
#   (module): PyramidNet(
#     (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(16, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn3): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
